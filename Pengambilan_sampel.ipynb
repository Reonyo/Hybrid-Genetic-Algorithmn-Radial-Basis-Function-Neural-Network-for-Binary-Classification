# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\Study\Kuliah Semester 5\Simulasi A2\Tugas Akhir\Deteksi Fraud.csv')

# %%
# Check Distribution
fraud_distribution = df['fraud_bool'].value_counts()
print(fraud_distribution)
# Out:
# 0    988971
# 1     11029
# Name: fraud_bool, dtype: int64

# %%
fraud_cases = df[df['fraud_bool'] == 1]
non_fraud_cases = df[df['fraud_bool'] == 0]

# 500 Sample for Fraud and 500 Sample for Non-Fraud
fraud_sample = fraud_cases.sample(n=500, random_state=42)
non_fraud_sample = non_fraud_cases.sample(n=500, random_state=42)

# Combining
balanced_df = pd.concat([fraud_sample, non_fraud_sample])
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Check
print(balanced_df['fraud_bool'].value_counts())
# Out:
# 0    500
# 1    500
# Name: fraud_bool, dtype: int64

# %%
columns_to_use = [
    'income',
    'credit_risk_score',
    'customer_age',
    'payment_type',
    'employment_status',
    'current_address_months_count',
    'fraud_bool'  # Target variable
]
# Create a new DataFrame with only the specified columns
df_resample = balanced_df[columns_to_use]

# %%
display(df_resample)
# Out:
#      income  credit_risk_score  customer_age payment_type employment_status  \
# 0       0.1                 98            20           AC                CA
# 1       0.1                264            20           AC                CA
# 2       0.8                223            20           AB                CA
# 3       0.6                 86            70           AB                CC
# 4       0.3                 61            30           AC                CA
# ..      ...                ...           ...          ...               ...
# 995     0.9                169            40           AC                CA
# 996     0.3                 15            70           AD                CC
# 997     0.7                104            40           AD                CA
# 998     0.9                177            60           AC                CB
# 999     0.7                102            30           AA                CB
#
#      current_address_months_count  fraud_bool
# ...

# %%
df_resample.to_csv(r'D:\Study\Kuliah Semester 5\Simulasi A2\Tugas Akhir\df_resample.csv', index=False)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\reyne\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\reyne\AppData\Local\Temp\ipykernel_17776\2203538725.py", line 1, in <module>
#     df_resample.to_csv(r'D:\Study\Kuliah Semester 5\Simulasi A2\Tugas Akhir\df_resample.csv', index=False)
#   File "c:\Users\reyne\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py", line 211, in wrapper
#     raise TypeError(msg)
#   File "c:\Users\reyne\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py", line 3720, in to_csv
#     str or None
#   File "c:\Users\reyne\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py", line 211, in wrapper
#     raise TypeError(msg)
# ...
